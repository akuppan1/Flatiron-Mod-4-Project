# %%
import pandas as pd

# %%
df_zillow = pd.read_csv('zillow_data.csv')
# pd.set_option("max_rows", None)
# pd.set_option("max_columns", None)
df_zillow
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
df_zillow['City'].unique()
# Out:
# array(['Chicago', 'McKinney', 'Katy', ..., 'Pine Valley', 'Esopus',
#        'Mount Crested Butte'], dtype=object)

# %%
len(df_zillow['State'].unique())
# Out:
# 51

# %%
def get_datetimes(df):
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')
yea = get_datetimes(df_zillow)

# %%
# for

# %%
df_zillow_1 = pd.melt(df_zillow, id_vars=['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName', 'SizeRank'])
df_zillow_1
# Out:
#          RegionID  RegionName                 City State              Metro  \
# 0           84654       60657              Chicago    IL            Chicago
# 1           90668       75070             McKinney    TX  Dallas-Fort Worth
# 2           91982       77494                 Katy    TX            Houston
# 3           84616       60614              Chicago    IL            Chicago
# 4           93144       79936              El Paso    TX            El Paso
# ...           ...         ...                  ...   ...                ...
# 3901590     58333        1338             Ashfield    MA    Greenfield Town
# 3901591     59107        3293            Woodstock    NH          Claremont
# 3901592     75672       40404                Berea    KY           Richmond
# 3901593     93733       81225  Mount Crested Butte    CO                NaN
# 3901594     95851       89155             Mesquite    NV          Las Vegas
#
#         CountyName  SizeRank variable     value
# ...

# %%
# a = df[df.param.notnull()].groupby('group')['param'].unique()
# print (pd.DataFrame.from_records(a.values.tolist()).stack().value_counts())

a = df_zillow_1.groupby('City').unique()
# print (pd.DataFrame.from_records(a.values.tolist()).stack().value_counts())
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-033a318c80f8> in <module>
#       2 # print (pd.DataFrame.from_records(a.values.tolist()).stack().value_counts())
#       3
# ----> 4 a = df_zillow_1.groupby('City').unique()
#       5 # print (pd.DataFrame.from_records(a.values.tolist()).stack().value_counts())
#       6 a
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'unique'

# %%
# def get_datetimes(df):
#     return pd.to_datetime(df.columns.values[7:], format='%Y-%m')


# get_datetimes(df_zillow_1)
# df_zillow_1

# %%
df_zillow_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901595 entries, 0 to 3901594
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   RegionName  int64
#  2   City        object
#  3   State       object
#  4   Metro       object
#  5   CountyName  object
#  6   SizeRank    int64
#  7   variable    object
#  8   value       float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 267.9+ MB

# %%
df_zillow_1.variable = pd.to_datetime(df_zillow_1.variable, format='%Y-%m')

# %%
df_zillow_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901595 entries, 0 to 3901594
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   RegionName  int64
#  2   City        object
#  3   State       object
#  4   Metro       object
#  5   CountyName  object
#  6   SizeRank    int64
#  7   variable    datetime64[ns]
#  8   value       float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 267.9+ MB

# %%
df_zillow_1
# Out:
#          RegionID  RegionName                 City State              Metro  \
# 0           84654       60657              Chicago    IL            Chicago
# 1           90668       75070             McKinney    TX  Dallas-Fort Worth
# 2           91982       77494                 Katy    TX            Houston
# 3           84616       60614              Chicago    IL            Chicago
# 4           93144       79936              El Paso    TX            El Paso
# ...           ...         ...                  ...   ...                ...
# 3901590     58333        1338             Ashfield    MA    Greenfield Town
# 3901591     59107        3293            Woodstock    NH          Claremont
# 3901592     75672       40404                Berea    KY           Richmond
# 3901593     93733       81225  Mount Crested Butte    CO                NaN
# 3901594     95851       89155             Mesquite    NV          Las Vegas
#
#         CountyName  SizeRank   variable     value
# ...

# %%
#Scatter plot, time as X, value as Y
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.scatter(df_zillow_1['variable'], df_zillow_1['value'])

# %%
#Too much shit in the graph, figure out how many cities im working with

# 1) group by state
#2) plot independant scatter plot per state

states = df_zillow['State'].unique().tolist()
# states

def independant_state_scatter(df):
    states = df_zillow['State'].unique().tolist()
    new_figure = plt.figure(figsize=(10,4))
    
    for state in states:

        PLOT SCATTTER PLOT OF ALL THE DATA POINTS INTO EACH SUBPLOT
# Out:
#   File "<ipython-input-26-aca2fd0a7220>", line 8
#     plt.MAKE A GRID OF 51 STATES GRIDS BLANKS
#              ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

states = df_zillow['State'].unique().tolist()


a = 17  # number of rows
b = 3  # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(14,100))

for i in states:
    plt.subplot(a, b, c)
    plt.title('{}, subplot: {}{}{}'.format(i, a, b, c))
    plt.xlabel(i)
    df_zillow_1['State'] == i
    X = df_zillow_1['variable'].groupby(df_zillow_1['State']).get_group(i)
    Y = df_zillow_1['value'].groupby(df_zillow_1['State']).get_group(i)    
    
    plt.scatter(X, Y)
    c = c + 1

plt.show()

# %%
# df_zillow_1['State'] == i
# print(i)

# %%
X = df_zillow_1['variable'].groupby(df_zillow_1['State']).get_group('VT')
Y = df_zillow_1['value'].groupby(df_zillow_1['State']).get_group('VT')


X_city = df_zillow_1['variable'].groupby(df_zillow_1['State'])
# Out:
# 6146      1996-04-01
# 6188      1996-04-01
# 7185      1996-04-01
# 9222      1996-04-01
# 10300     1996-04-01
#              ...
# 3900077   2018-04-01
# 3900610   2018-04-01
# 3901105   2018-04-01
# 3901143   2018-04-01
# 3901153   2018-04-01
# Name: variable, Length: 4240, dtype: datetime64[ns]

# %%
# fig = plt.figure(figsize=(14,14))
# plt.scatter(X, Y)

# %%
df_zillow_3 = df_zillow.groupby('State')
df_zillow_3['State'].head()
# Out:
# 0        IL
# 1        TX
# 2        TX
# 3        IL
# 4        TX
#          ..
# 6146     VT
# 6188     VT
# 7185     VT
# 9222     VT
# 10300    VT
# Name: State, Length: 255, dtype: object

# %%
# print(grouped_df.get_group("Alex"))
df_zillow_3.get_group(i)
#So it makes a groupby instance which i have to call get_group method in order to show only those things
# Out:
#        RegionID  RegionName        City State             Metro CountyName  \
# 0         84654       60657     Chicago    IL           Chicago       Cook
# 3         84616       60614     Chicago    IL           Chicago       Cook
# 7         84640       60640     Chicago    IL           Chicago       Cook
# 16        84646       60647     Chicago    IL           Chicago       Cook
# 19        84620       60618     Chicago    IL           Chicago       Cook
# ...         ...         ...         ...   ...               ...        ...
# 14609     85203       61859       Ogden    IL  Champaign-Urbana  Champaign
# 14615     85235       61931    Humboldt    IL        Charleston      Coles
# 14630     85016       61488      Wataga    IL         Galesburg       Knox
# 14640     85119       61733  Deer Creek    IL            Peoria   Tazewell
# 14664     85067       61572  Yates City    IL         Galesburg       Knox
#
# ...
